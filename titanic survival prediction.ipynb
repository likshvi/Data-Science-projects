# %% [markdown]
# <font size=5>This the the Exploratory data analysis of Titanic Dataset from kaggle.</font>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from pandas.plotting import scatter_matrix
import seaborn as sns

# %%
path="C:\\Users\\Likshvit\\Desktop\\datafiles\\all\\train.csv"

# %%
df=pd.read_csv(path)

# %% [markdown]
# <font size=4>Taking a look on the data.</font>

# %%
print(df.head(5))
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
# PassengerId    891 non-null int64
# Survived       891 non-null int64
# Pclass         891 non-null int64
# Name           891 non-null object
# Sex            891 non-null object
# Age            714 non-null float64
# SibSp          891 non-null int64
# Parch          891 non-null int64
# Ticket         891 non-null object
# Fare           891 non-null float64
# Cabin          204 non-null object
# Embarked       889 non-null object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.6+ KB

# %% [markdown]
# <font size=4>Finding some basic statistical values from data.</font>

# %%
df.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
df.shape
# Out:
# (891, 12)

# %% [markdown]
# <font size=4>Boxplot visualization .</font>

# %%
df.plot(kind='box', subplots=True)
# Out:
# PassengerId       Axes(0.125,0.125;0.0945122x0.775)
# Survived       Axes(0.238415,0.125;0.0945122x0.775)
# Pclass         Axes(0.351829,0.125;0.0945122x0.775)
# Age            Axes(0.465244,0.125;0.0945122x0.775)
# SibSp          Axes(0.578659,0.125;0.0945122x0.775)
# Parch          Axes(0.692073,0.125;0.0945122x0.775)
# Fare           Axes(0.805488,0.125;0.0945122x0.775)
# dtype: object

# %% [markdown]
# <font size=4>Histograms.</font>

# %%
df.hist(figsize=(15,25))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x0000008C9CB76470>,
# ...
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000008C9CE4E518>]], dtype=object)

# %% [markdown]
# <font size=4>Finding out data based on some filters .</font>

# %%
df.loc[(df['Age']>30)&(df['Sex']=='female')&df['Pclass'].isin(['1','2'])]
# Out:
#      PassengerId  Survived  Pclass  \
# 1              2         1       1
# 3              4         1       1
# 11            12         1       1
# 15            16         1       2
# 52            53         1       1
# 61            62         1       1
# 98            99         1       2
# 123          124         1       2
# 161          162         1       2
# 177          178         0       1
# 190          191         1       2
# 194          195         1       1
# 195          196         1       1
# 211          212         1       2
# 215          216         1       1
# 218          219         1       1
# 230          231         1       1
# 258          259         1       1
# 259          260         1       2
# 268          269         1       1
# 269          270         1       1
# 272          273         1       2
# 275          276         1       1
# 299          300         1       1
# 318          319         1       1
# ...

# %% [markdown]
# <font size=4>Strength of people per class</font>

# %%
print(df.groupby('Pclass').size())
# Out:
# Pclass
# 1    216
# 2    184
# 3    491
# dtype: int64

# %% [markdown]
# <font size=4>Number of null values per column.</font>

# %%
#pd.isnull(df).count()
df.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %% [markdown]
# <font size=4>Distribution of survived people per class.</font>

# %%
sns.countplot(df['Pclass'],hue=df['Survived'])

# %% [markdown]
# <font size=4>Age distribution of people per class</font>

# %%
g = sns.FacetGrid(df, col='Pclass')
g.map(sns.distplot, 'Age')

# %% [markdown]
# <font size=4>Table for finding relation between some columns.</font>

# %%
df[["Pclass", "Sex","Survived"]].groupby(["Pclass", "Sex"]).mean()
# Out:
#                Survived
# Pclass Sex
# 1      female  0.968085
#        male    0.368852
# 2      female  0.921053
#        male    0.157407
# 3      female  0.500000
#        male    0.135447

# %% [markdown]
# <font size=4>Visualization of correlation between some columns.</font>

# %%
g = sns.heatmap(df[["Survived","SibSp","Parch","Age","Fare"]].corr(),annot=True)
